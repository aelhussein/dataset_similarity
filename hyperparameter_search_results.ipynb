# %%
ROOT_DIR = '/gpfs/commons/groups/gursoy_lab/aelhussein/ot_cost/otcost_fl'
import pandas as pd
import sys
import numpy as np
import pickle

# %%
def load_results(DATASET, reg_param = False):
    if reg_param:
        with open(f'{ROOT_DIR}/results/reg_param_tuning/{DATASET}_reg_param_tuning.pkl', 'rb') as f :
            results = pickle.load(f)
    else:
        with open(f'{ROOT_DIR}/results/lr_tuning/{DATASET}_lr_tuning.pkl', 'rb') as f :
            results = pickle.load(f)
    return results

# %% [markdown]
# # LR only

# %% [markdown]
# ### Synthetic

# %%
DATASET = 'Synthetic'
lr_tuning = load_results(DATASET, reg_param = False)

# %%
len(lr_tuning[0.1]['single'][0.0005]['global']['losses'])
# Out:
# 1

# %%
def get_structure(d, indent=0):
    structure = {}
    for key, value in d.items():
        if isinstance(value, dict):
            structure[key] = get_structure(value)
        elif isinstance(value, list) and value and isinstance(value[0], dict):
            structure[key] = [get_structure(value[0])]
        else:
            structure[key] = type(value).__name__
    return structure

# Example usage
from pprint import pprint
structure = get_structure(lr_tuning)
pprint(structure)
# Out:
# {0.1: {'ditto': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_1': {'losses': 'list',
#                                                  'scores': 'list'},
#                                     'client_2': {'losses': 'list',
#                                                  'scores': 'list'}}}},
#        'fedavg': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'joint': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_joint': {'losses': 'list',
#                                                      'scores': 'list'}}}},
#        'pfedme': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'single': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}}},
#  0.2: {'ditto': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_1': {'losses': 'list',
#                                                  'scores': 'list'},
#                                     'client_2': {'losses': 'list',
#                                                  'scores': 'list'}}}},
#        'fedavg': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'joint': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_joint': {'losses': 'list',
#                                                      'scores': 'list'}}}},
#        'pfedme': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'single': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}}},
#  0.3: {'ditto': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_1': {'losses': 'list',
#                                                  'scores': 'list'},
#                                     'client_2': {'losses': 'list',
#                                                  'scores': 'list'}}}},
#        'fedavg': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'joint': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_joint': {'losses': 'list',
#                                                      'scores': 'list'}}}},
#        'pfedme': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'single': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}}},
#  0.4: {'ditto': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_1': {'losses': 'list',
#                                                  'scores': 'list'},
#                                     'client_2': {'losses': 'list',
#                                                  'scores': 'list'}}}},
#        'fedavg': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'joint': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_joint': {'losses': 'list',
#                                                      'scores': 'list'}}}},
#        'pfedme': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'single': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}}},
#  0.5: {'ditto': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_1': {'losses': 'list',
#                                                  'scores': 'list'},
#                                     'client_2': {'losses': 'list',
#                                                  'scores': 'list'}}}},
#        'fedavg': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'joint': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                           'sites': {'client_joint': {'losses': 'list',
#                                                      'scores': 'list'}}}},
#        'pfedme': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}},
#        'single': {0.0005: {'global': {'losses': 'list', 'scores': 'list'},
#                            'sites': {'client_1': {'losses': 'list',
#                                                   'scores': 'list'},
#                                      'client_2': {'losses': 'list',
#                                                   'scores': 'list'}}}}}}

# %%
def analyze_results(data):
    """
    Analyzes federated learning results to find best LR rates and scores for each cost-server combination.
    
    Args:
        data: Nested dictionary containing the results
        
    Returns:
        Dictionary with analysis results for each cost-server combination
    """
    analysis_results = {}
    
    # Iterate through each cost level
    for cost in data.keys():
        analysis_results[cost] = {}
        
        # Iterate through each server type
        for server_type in data[cost].keys():
            min_loss = float('inf')
            best_lr = None
            best_score = float('-inf')
            
            # Iterate through learning rates
            for lr in data[cost][server_type].keys():
                # Get global losses for this configuration
                global_losses = data[cost][server_type][lr]['global']['losses']
                global_scores = data[cost][server_type][lr]['global']['scores']
                
                # Calculate average of minimum losses from each run
                if isinstance(global_losses, list):
                    avg_min_loss = sum(min(run) if isinstance(run, list) else float('inf') 
                                     for run in global_losses) / len(global_losses)
                    
                    # Update if this is the best loss we've seen for this cost-server combo
                    if avg_min_loss < min_loss:
                        min_loss = avg_min_loss
                        best_lr = lr
                
                # Track best score
                if isinstance(global_scores, list):
                    max_score = max(max(run) if isinstance(run, list) else float('-inf') 
                                  for run in global_scores)
                    best_score = max(best_score, max_score)
            
            analysis_results[cost][server_type] = {
                'best_lr': best_lr,
                'min_loss': min_loss,
                'best_score': best_score
            }
    
    return analysis_results

# Example usage:
results = analyze_results(lr_tuning)

# Print results in a formatted way
for cost in sorted(results.keys()):
    print(f"\nCost: {cost}")
    for server_type in sorted(results[cost].keys()):
        res = results[cost][server_type]
        print(f"  {server_type}:")
        print(f"    Best LR: {res['best_lr']}")
        print(f"    Min Loss: {res['min_loss']:.4f}")
        print(f"    Best Score: {res['best_score']:.4f}")
# Out:
# Cost: 0.1
#   ditto:
#     Best LR: 0.0005
#     Min Loss: 1.4320
#     Best Score: 0.7195
#   fedavg:
#     Best LR: 0.0005
#     Min Loss: 0.7146
#     Best Score: 0.7208
#   joint:
#     Best LR: 0.0005
#     Min Loss: 1.0868
#     Best Score: 0.6196
#   pfedme:
#     Best LR: 0.0005
#     Min Loss: 0.8717
#     Best Score: 0.7519
#   single:
#     Best LR: 0.0005
#     Min Loss: 0.7199
#     Best Score: 0.7554
#
# Cost: 0.2
#   ditto:
#     Best LR: 0.0005
#     Min Loss: 1.0990
#     Best Score: 0.1396
#   fedavg:
#     Best LR: 0.0005
#     Min Loss: 0.7972
#     Best Score: 0.7843
#   joint:
#     Best LR: 0.0005
#     Min Loss: 1.8610
#     Best Score: 0.7059
#   pfedme:
#     Best LR: 0.0005
#     Min Loss: 1.7726
#     Best Score: 0.7478
#   single:
#     Best LR: 0.0005
#     Min Loss: 0.9681
#     Best Score: 0.7369
#
# Cost: 0.3
#   ditto:
#     Best LR: 0.0005
#     Min Loss: 0.7982
#     Best Score: 0.6172
#   fedavg:
#     Best LR: 0.0005
#     Min Loss: 0.7940
#     Best Score: 0.6361
#   joint:
#     Best LR: 0.0005
#     Min Loss: 0.8290
#     Best Score: 0.7538
#   pfedme:
#     Best LR: 0.0005
#     Min Loss: 0.7435
#     Best Score: 0.6011
#   single:
#     Best LR: 0.0005
#     Min Loss: 0.7238
#     Best Score: 0.6299
#
# Cost: 0.4
#   ditto:
#     Best LR: 0.0005
#     Min Loss: 0.7403
#     Best Score: 0.6670
#   fedavg:
#     Best LR: 0.0005
#     Min Loss: 0.9213
#     Best Score: 0.6154
#   joint:
#     Best LR: 0.0005
#     Min Loss: 1.0778
#     Best Score: 0.6590
#   pfedme:
#     Best LR: 0.0005
#     Min Loss: 0.8322
#     Best Score: 0.6225
#   single:
#     Best LR: 0.0005
#     Min Loss: 0.8248
#     Best Score: 0.3512
#
# Cost: 0.5
#   ditto:
#     Best LR: 0.0005
#     Min Loss: 0.9138
#     Best Score: 0.6585
#   fedavg:
#     Best LR: 0.0005
#     Min Loss: 0.8714
#     Best Score: 0.7005
#   joint:
#     Best LR: 0.0005
#     Min Loss: 1.0875
#     Best Score: 0.6737
#   pfedme:
#     Best LR: 0.0005
#     Min Loss: 1.2708
#     Best Score: 0.6585
#   single:
#     Best LR: 0.0005
#     Min Loss: 0.7880
#     Best Score: 0.6823

# %%
# Process the dictionary
results = {}

for cost, server_types in lr_tuning.items():
    results[cost] = {}
    for server_type, lr_rates in server_types.items():
        best_lr = None
        best_loss_avg = float("inf")
        best_score = float("-inf")
        
        for lr, values in lr_rates.items():
            # Calculate average of the minimum global losses
            global_losses = values["global"]["losses"]
            min_losses = [min(run) for run in global_losses]  # Minimum loss for each run
            avg_min_loss = sum(min_losses) / len(min_losses)  # Average of the minimums

            # Update the best LR for average minimum loss
            if avg_min_loss < best_loss_avg:
                best_loss_avg = avg_min_loss
                best_lr = lr
            
        # Update the best score
        best_score = [max(m) for m in lr_rates[lr]["global"]["scores"]]
        # Store results for this server type
        results[cost][server_type] = {
            "best_lr": best_lr,
            "best_avg_min_loss": best_loss_avg,
            "best_score": best_score,
        }

# Print results
import pprint
pprint.pprint(results)
# Out:
# {0.1: {'ditto': {'best_avg_min_loss': 1.4320052862167358,
#                  'best_lr': 0.0005,
#                  'best_score': [0.7194877951180472]},
#        'fedavg': {'best_avg_min_loss': 0.7146069705486298,
#                   'best_lr': 0.0005,
#                   'best_score': [0.7207670134102018]},
#        'joint': {'best_avg_min_loss': 1.0867972373962402,
#                  'best_lr': 0.0005,
#                  'best_score': [0.6195652173913043]},
#        'pfedme': {'best_avg_min_loss': 0.8717212975025177,
#                   'best_lr': 0.0005,
#                   'best_score': [0.7518593644354293]},
#        'single': {'best_avg_min_loss': 0.7199075520038605,
#                   'best_lr': 0.0005,
#                   'best_score': [0.7554347826086957]}},
#  0.2: {'ditto': {'best_avg_min_loss': 1.0989928841590881,
#                  'best_lr': 0.0005,
#                  'best_score': [0.13958810068649885]},
#        'fedavg': {'best_avg_min_loss': 0.797239363193512,
#                   'best_lr': 0.0005,
#                   'best_score': [0.7842748980780432]},
#        'joint': {'best_avg_min_loss': 1.861012578010559,
#                  'best_lr': 0.0005,
#                  'best_score': [0.7058823529411765]},
#        'pfedme': {'best_avg_min_loss': 1.7725593745708466,
#                   'best_lr': 0.0005,
#                   'best_score': [0.7477551020408163]},
#        'single': {'best_avg_min_loss': 0.9681197702884674,
#                   'best_lr': 0.0005,
#                   'best_score': [0.7369387755102041]}},
#  0.3: {'ditto': {'best_avg_min_loss': 0.7982223927974701,
#                  'best_lr': 0.0005,
#                  'best_score': [0.6172161172161172]},
#        'fedavg': {'best_avg_min_loss': 0.7940331101417542,
#                   'best_lr': 0.0005,
#                   'best_score': [0.6360598770382251]},
#        'joint': {'best_avg_min_loss': 0.8290395736694336,
#                  'best_lr': 0.0005,
#                  'best_score': [0.7537688442211056]},
#        'pfedme': {'best_avg_min_loss': 0.7435106635093689,
#                   'best_lr': 0.0005,
#                   'best_score': [0.6010511227902533]},
#        'single': {'best_avg_min_loss': 0.7237908840179443,
#                   'best_lr': 0.0005,
#                   'best_score': [0.6299145299145299]}},
#  0.4: {'ditto': {'best_avg_min_loss': 0.740257740020752,
#                  'best_lr': 0.0005,
#                  'best_score': [0.6670071501532175]},
#        'fedavg': {'best_avg_min_loss': 0.9212824106216431,
#                   'best_lr': 0.0005,
#                   'best_score': [0.6153846153846154]},
#        'joint': {'best_avg_min_loss': 1.0777791738510132,
#                  'best_lr': 0.0005,
#                  'best_score': [0.6589595375722543]},
#        'pfedme': {'best_avg_min_loss': 0.8322181105613708,
#                   'best_lr': 0.0005,
#                   'best_score': [0.6224701608718215]},
#        'single': {'best_avg_min_loss': 0.8248177766799927,
#                   'best_lr': 0.0005,
#                   'best_score': [0.35119047619047616]}},
#  0.5: {'ditto': {'best_avg_min_loss': 0.9138006567955017,
#                  'best_lr': 0.0005,
#                  'best_score': [0.6585144927536233]},
#        'fedavg': {'best_avg_min_loss': 0.8713938295841217,
#                   'best_lr': 0.0005,
#                   'best_score': [0.700517836593786]},
#        'joint': {'best_avg_min_loss': 1.0875098705291748,
#                  'best_lr': 0.0005,
#                  'best_score': [0.6736842105263158]},
#        'pfedme': {'best_avg_min_loss': 1.2708350121974945,
#                   'best_lr': 0.0005,
#                   'best_score': [0.6585144927536233]},
#        'single': {'best_avg_min_loss': 0.7879990041255951,
#                   'best_lr': 0.0005,
#                   'best_score': [0.682258064516129]}}}

# %%
import torch

# %%
efficientnet = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_efficientnet_b0', pretrained=True)
# Out:
# Using cache found in /gpfs/commons/home/aelhussein/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# /gpfs/commons/home/aelhussein/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /gpfs/commons/home/aelhussein/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(

# %%
for name, module in efficientnet.named_modules():
    print(f"Layer name: {name}")
    print(module)
    print("----------")
# Out:
# Layer name:
# EfficientNet(
#   (stem): Sequential(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (activation): SiLU(inplace=True)
#   )
#   (layers): Sequential(
#     (0): Sequential(
#       (block0): MBConvBlock(
#         (depsep): Sequential(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=32, out_features=8, bias=True)
#           (expand): Linear(in_features=8, out_features=32, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#     )
#     (1): Sequential(
#       (block0): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=96, out_features=4, bias=True)
#           (expand): Linear(in_features=4, out_features=96, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block1): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=144, out_features=6, bias=True)
#           (expand): Linear(in_features=6, out_features=144, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#     )
#     (2): Sequential(
#       (block0): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=144, out_features=6, bias=True)
#           (expand): Linear(in_features=6, out_features=144, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block1): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=240, out_features=10, bias=True)
#           (expand): Linear(in_features=10, out_features=240, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#     )
#     (3): Sequential(
#       (block0): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=240, out_features=10, bias=True)
#           (expand): Linear(in_features=10, out_features=240, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block1): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=480, out_features=20, bias=True)
#           (expand): Linear(in_features=20, out_features=480, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block2): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=480, out_features=20, bias=True)
#           (expand): Linear(in_features=20, out_features=480, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#     )
#     (4): Sequential(
#       (block0): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#           (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=480, out_features=20, bias=True)
#           (expand): Linear(in_features=20, out_features=480, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block1): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#           (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=672, out_features=28, bias=True)
#           (expand): Linear(in_features=28, out_features=672, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block2): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#           (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=672, out_features=28, bias=True)
#           (expand): Linear(in_features=28, out_features=672, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#     )
#     (5): Sequential(
#       (block0): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=672, out_features=28, bias=True)
#           (expand): Linear(in_features=28, out_features=672, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block1): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#           (expand): Linear(in_features=48, out_features=1152, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block2): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#           (expand): Linear(in_features=48, out_features=1152, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#       (block3): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#           (expand): Linear(in_features=48, out_features=1152, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#     )
#     (6): Sequential(
#       (block0): MBConvBlock(
#         (expand): Sequential(
#           (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (depsep): Sequential(
#           (conv): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#           (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (se): SequentialSqueezeAndExcitation(
#           (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#           (expand): Linear(in_features=48, out_features=1152, bias=True)
#           (activation): SiLU(inplace=True)
#           (sigmoid): Sigmoid()
#           (mul_a_quantizer): Identity()
#           (mul_b_quantizer): Identity()
#         )
#         (proj): Sequential(
#           (conv): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         )
#         (residual_quantizer): Identity()
#       )
#     )
#   )
#   (features): Sequential(
#     (conv): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (activation): SiLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (pooling): AdaptiveAvgPool2d(output_size=1)
#     (squeeze): Flatten()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (fc): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )
# ----------
# Layer name: stem
# Sequential(
#   (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (activation): SiLU(inplace=True)
# )
# ----------
# Layer name: stem.conv
# Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# ----------
# Layer name: stem.bn
# BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: stem.activation
# SiLU(inplace=True)
# ----------
# Layer name: layers
# Sequential(
#   (0): Sequential(
#     (block0): MBConvBlock(
#       (depsep): Sequential(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=32, out_features=8, bias=True)
#         (expand): Linear(in_features=8, out_features=32, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#   )
#   (1): Sequential(
#     (block0): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=96, out_features=4, bias=True)
#         (expand): Linear(in_features=4, out_features=96, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block1): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=144, out_features=6, bias=True)
#         (expand): Linear(in_features=6, out_features=144, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#   )
#   (2): Sequential(
#     (block0): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=144, out_features=6, bias=True)
#         (expand): Linear(in_features=6, out_features=144, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block1): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=240, out_features=10, bias=True)
#         (expand): Linear(in_features=10, out_features=240, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#   )
#   (3): Sequential(
#     (block0): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#         (bn): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=240, out_features=10, bias=True)
#         (expand): Linear(in_features=10, out_features=240, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block1): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=480, out_features=20, bias=True)
#         (expand): Linear(in_features=20, out_features=480, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block2): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=480, out_features=20, bias=True)
#         (expand): Linear(in_features=20, out_features=480, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#   )
#   (4): Sequential(
#     (block0): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#         (bn): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=480, out_features=20, bias=True)
#         (expand): Linear(in_features=20, out_features=480, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block1): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=672, out_features=28, bias=True)
#         (expand): Linear(in_features=28, out_features=672, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block2): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=672, out_features=28, bias=True)
#         (expand): Linear(in_features=28, out_features=672, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#   )
#   (5): Sequential(
#     (block0): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#         (bn): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=672, out_features=28, bias=True)
#         (expand): Linear(in_features=28, out_features=672, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block1): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#         (expand): Linear(in_features=48, out_features=1152, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block2): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#         (expand): Linear(in_features=48, out_features=1152, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#     (block3): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#         (expand): Linear(in_features=48, out_features=1152, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#   )
#   (6): Sequential(
#     (block0): MBConvBlock(
#       (expand): Sequential(
#         (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (depsep): Sequential(
#         (conv): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (se): SequentialSqueezeAndExcitation(
#         (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#         (expand): Linear(in_features=48, out_features=1152, bias=True)
#         (activation): SiLU(inplace=True)
#         (sigmoid): Sigmoid()
#         (mul_a_quantizer): Identity()
#         (mul_b_quantizer): Identity()
#       )
#       (proj): Sequential(
#         (conv): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
#       (residual_quantizer): Identity()
#     )
#   )
# )
# ----------
# Layer name: layers.0
# Sequential(
#   (block0): MBConvBlock(
#     (depsep): Sequential(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (se): SequentialSqueezeAndExcitation(
#       (squeeze): Linear(in_features=32, out_features=8, bias=True)
#       (expand): Linear(in_features=8, out_features=32, bias=True)
#       (activation): SiLU(inplace=True)
#       (sigmoid): Sigmoid()
#       (mul_a_quantizer): Identity()
#       (mul_b_quantizer): Identity()
#     )
#     (proj): Sequential(
#       (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (residual_quantizer): Identity()
#   )
# )
# ----------
# Layer name: layers.0.block0
# MBConvBlock(
#   (depsep): Sequential(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (se): SequentialSqueezeAndExcitation(
#     (squeeze): Linear(in_features=32, out_features=8, bias=True)
#     (expand): Linear(in_features=8, out_features=32, bias=True)
#     (activation): SiLU(inplace=True)
#     (sigmoid): Sigmoid()
#     (mul_a_quantizer): Identity()
#     (mul_b_quantizer): Identity()
#   )
#   (proj): Sequential(
#     (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   )
#   (residual_quantizer): Identity()
# )
# ----------
# Layer name: layers.0.block0.depsep
# Sequential(
#   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (bn): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.0.block0.depsep.conv
# Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
# ----------
# Layer name: layers.0.block0.depsep.bn
# BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.0.block0.depsep.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.0.block0.se
# SequentialSqueezeAndExcitation(
#   (squeeze): Linear(in_features=32, out_features=8, bias=True)
#   (expand): Linear(in_features=8, out_features=32, bias=True)
#   (activation): SiLU(inplace=True)
#   (sigmoid): Sigmoid()
#   (mul_a_quantizer): Identity()
#   (mul_b_quantizer): Identity()
# )
# ----------
# Layer name: layers.0.block0.se.squeeze
# Linear(in_features=32, out_features=8, bias=True)
# ----------
# Layer name: layers.0.block0.se.expand
# Linear(in_features=8, out_features=32, bias=True)
# ----------
# Layer name: layers.0.block0.se.activation
# SiLU(inplace=True)
# ----------
# Layer name: layers.0.block0.se.sigmoid
# Sigmoid()
# ----------
# Layer name: layers.0.block0.se.mul_a_quantizer
# Identity()
# ----------
# Layer name: layers.0.block0.se.mul_b_quantizer
# Identity()
# ----------
# Layer name: layers.0.block0.proj
# Sequential(
#   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# )
# ----------
# Layer name: layers.0.block0.proj.conv
# Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.0.block0.proj.bn
# BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.0.block0.residual_quantizer
# Identity()
# ----------
# Layer name: layers.1
# Sequential(
#   (block0): MBConvBlock(
#     (expand): Sequential(
#       (conv): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (depsep): Sequential(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (se): SequentialSqueezeAndExcitation(
#       (squeeze): Linear(in_features=96, out_features=4, bias=True)
#       (expand): Linear(in_features=4, out_features=96, bias=True)
#       (activation): SiLU(inplace=True)
#       (sigmoid): Sigmoid()
#       (mul_a_quantizer): Identity()
#       (mul_b_quantizer): Identity()
#     )
#     (proj): Sequential(
#       (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (residual_quantizer): Identity()
#   )
#   (block1): MBConvBlock(
#     (expand): Sequential(
#       (conv): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (depsep): Sequential(
#       (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#       (bn): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (se): SequentialSqueezeAndExcitation(
#       (squeeze): Linear(in_features=144, out_features=6, bias=True)
#       (expand): Linear(in_features=6, out_features=144, bias=True)
#       (activation): SiLU(inplace=True)
#       (sigmoid): Sigmoid()
#       (mul_a_quantizer): Identity()
#       (mul_b_quantizer): Identity()
#     )
#     (proj): Sequential(
#       (conv): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (residual_quantizer): Identity()
#   )
# )
# ----------
# Layer name: layers.1.block0
# MBConvBlock(
#   (expand): Sequential(
#     (conv): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (depsep): Sequential(
#     (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (se): SequentialSqueezeAndExcitation(
#     (squeeze): Linear(in_features=96, out_features=4, bias=True)
#     (expand): Linear(in_features=4, out_features=96, bias=True)
#     (activation): SiLU(inplace=True)
#     (sigmoid): Sigmoid()
#     (mul_a_quantizer): Identity()
#     (mul_b_quantizer): Identity()
#   )
#   (proj): Sequential(
#     (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   )
#   (residual_quantizer): Identity()
# )
# ----------
# Layer name: layers.1.block0.expand
# Sequential(
#   (conv): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.1.block0.expand.conv
# Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.1.block0.expand.bn
# BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.1.block0.expand.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.1.block0.depsep
# Sequential(
#   (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
# ...
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.5.block1.expand.conv
# Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.5.block1.expand.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block1.expand.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block1.depsep
# Sequential(
#   (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#   (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.5.block1.depsep.conv
# Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
# ----------
# Layer name: layers.5.block1.depsep.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block1.depsep.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block1.se
# SequentialSqueezeAndExcitation(
#   (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#   (expand): Linear(in_features=48, out_features=1152, bias=True)
#   (activation): SiLU(inplace=True)
#   (sigmoid): Sigmoid()
#   (mul_a_quantizer): Identity()
#   (mul_b_quantizer): Identity()
# )
# ----------
# Layer name: layers.5.block1.se.squeeze
# Linear(in_features=1152, out_features=48, bias=True)
# ----------
# Layer name: layers.5.block1.se.expand
# Linear(in_features=48, out_features=1152, bias=True)
# ----------
# Layer name: layers.5.block1.se.activation
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block1.se.sigmoid
# Sigmoid()
# ----------
# Layer name: layers.5.block1.se.mul_a_quantizer
# Identity()
# ----------
# Layer name: layers.5.block1.se.mul_b_quantizer
# Identity()
# ----------
# Layer name: layers.5.block1.proj
# Sequential(
#   (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# )
# ----------
# Layer name: layers.5.block1.proj.conv
# Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.5.block1.proj.bn
# BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block1.residual_quantizer
# Identity()
# ----------
# Layer name: layers.5.block2
# MBConvBlock(
#   (expand): Sequential(
#     (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (depsep): Sequential(
#     (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#     (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (se): SequentialSqueezeAndExcitation(
#     (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#     (expand): Linear(in_features=48, out_features=1152, bias=True)
#     (activation): SiLU(inplace=True)
#     (sigmoid): Sigmoid()
#     (mul_a_quantizer): Identity()
#     (mul_b_quantizer): Identity()
#   )
#   (proj): Sequential(
#     (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   )
#   (residual_quantizer): Identity()
# )
# ----------
# Layer name: layers.5.block2.expand
# Sequential(
#   (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.5.block2.expand.conv
# Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.5.block2.expand.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block2.expand.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block2.depsep
# Sequential(
#   (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#   (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.5.block2.depsep.conv
# Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
# ----------
# Layer name: layers.5.block2.depsep.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block2.depsep.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block2.se
# SequentialSqueezeAndExcitation(
#   (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#   (expand): Linear(in_features=48, out_features=1152, bias=True)
#   (activation): SiLU(inplace=True)
#   (sigmoid): Sigmoid()
#   (mul_a_quantizer): Identity()
#   (mul_b_quantizer): Identity()
# )
# ----------
# Layer name: layers.5.block2.se.squeeze
# Linear(in_features=1152, out_features=48, bias=True)
# ----------
# Layer name: layers.5.block2.se.expand
# Linear(in_features=48, out_features=1152, bias=True)
# ----------
# Layer name: layers.5.block2.se.activation
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block2.se.sigmoid
# Sigmoid()
# ----------
# Layer name: layers.5.block2.se.mul_a_quantizer
# Identity()
# ----------
# Layer name: layers.5.block2.se.mul_b_quantizer
# Identity()
# ----------
# Layer name: layers.5.block2.proj
# Sequential(
#   (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# )
# ----------
# Layer name: layers.5.block2.proj.conv
# Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.5.block2.proj.bn
# BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block2.residual_quantizer
# Identity()
# ----------
# Layer name: layers.5.block3
# MBConvBlock(
#   (expand): Sequential(
#     (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (depsep): Sequential(
#     (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#     (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (se): SequentialSqueezeAndExcitation(
#     (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#     (expand): Linear(in_features=48, out_features=1152, bias=True)
#     (activation): SiLU(inplace=True)
#     (sigmoid): Sigmoid()
#     (mul_a_quantizer): Identity()
#     (mul_b_quantizer): Identity()
#   )
#   (proj): Sequential(
#     (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   )
#   (residual_quantizer): Identity()
# )
# ----------
# Layer name: layers.5.block3.expand
# Sequential(
#   (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.5.block3.expand.conv
# Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.5.block3.expand.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block3.expand.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block3.depsep
# Sequential(
#   (conv): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#   (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.5.block3.depsep.conv
# Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
# ----------
# Layer name: layers.5.block3.depsep.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block3.depsep.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block3.se
# SequentialSqueezeAndExcitation(
#   (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#   (expand): Linear(in_features=48, out_features=1152, bias=True)
#   (activation): SiLU(inplace=True)
#   (sigmoid): Sigmoid()
#   (mul_a_quantizer): Identity()
#   (mul_b_quantizer): Identity()
# )
# ----------
# Layer name: layers.5.block3.se.squeeze
# Linear(in_features=1152, out_features=48, bias=True)
# ----------
# Layer name: layers.5.block3.se.expand
# Linear(in_features=48, out_features=1152, bias=True)
# ----------
# Layer name: layers.5.block3.se.activation
# SiLU(inplace=True)
# ----------
# Layer name: layers.5.block3.se.sigmoid
# Sigmoid()
# ----------
# Layer name: layers.5.block3.se.mul_a_quantizer
# Identity()
# ----------
# Layer name: layers.5.block3.se.mul_b_quantizer
# Identity()
# ----------
# Layer name: layers.5.block3.proj
# Sequential(
#   (conv): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# )
# ----------
# Layer name: layers.5.block3.proj.conv
# Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.5.block3.proj.bn
# BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.5.block3.residual_quantizer
# Identity()
# ----------
# Layer name: layers.6
# Sequential(
#   (block0): MBConvBlock(
#     (expand): Sequential(
#       (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (depsep): Sequential(
#       (conv): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#       (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (se): SequentialSqueezeAndExcitation(
#       (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#       (expand): Linear(in_features=48, out_features=1152, bias=True)
#       (activation): SiLU(inplace=True)
#       (sigmoid): Sigmoid()
#       (mul_a_quantizer): Identity()
#       (mul_b_quantizer): Identity()
#     )
#     (proj): Sequential(
#       (conv): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (residual_quantizer): Identity()
#   )
# )
# ----------
# Layer name: layers.6.block0
# MBConvBlock(
#   (expand): Sequential(
#     (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (depsep): Sequential(
#     (conv): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#     (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (se): SequentialSqueezeAndExcitation(
#     (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#     (expand): Linear(in_features=48, out_features=1152, bias=True)
#     (activation): SiLU(inplace=True)
#     (sigmoid): Sigmoid()
#     (mul_a_quantizer): Identity()
#     (mul_b_quantizer): Identity()
#   )
#   (proj): Sequential(
#     (conv): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   )
#   (residual_quantizer): Identity()
# )
# ----------
# Layer name: layers.6.block0.expand
# Sequential(
#   (conv): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.6.block0.expand.conv
# Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.6.block0.expand.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.6.block0.expand.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.6.block0.depsep
# Sequential(
#   (conv): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#   (bn): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (act): SiLU(inplace=True)
# )
# ----------
# Layer name: layers.6.block0.depsep.conv
# Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
# ----------
# Layer name: layers.6.block0.depsep.bn
# BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.6.block0.depsep.act
# SiLU(inplace=True)
# ----------
# Layer name: layers.6.block0.se
# SequentialSqueezeAndExcitation(
#   (squeeze): Linear(in_features=1152, out_features=48, bias=True)
#   (expand): Linear(in_features=48, out_features=1152, bias=True)
#   (activation): SiLU(inplace=True)
#   (sigmoid): Sigmoid()
#   (mul_a_quantizer): Identity()
#   (mul_b_quantizer): Identity()
# )
# ----------
# Layer name: layers.6.block0.se.squeeze
# Linear(in_features=1152, out_features=48, bias=True)
# ----------
# Layer name: layers.6.block0.se.expand
# Linear(in_features=48, out_features=1152, bias=True)
# ----------
# Layer name: layers.6.block0.se.activation
# SiLU(inplace=True)
# ----------
# Layer name: layers.6.block0.se.sigmoid
# Sigmoid()
# ----------
# Layer name: layers.6.block0.se.mul_a_quantizer
# Identity()
# ----------
# Layer name: layers.6.block0.se.mul_b_quantizer
# Identity()
# ----------
# Layer name: layers.6.block0.proj
# Sequential(
#   (conv): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# )
# ----------
# Layer name: layers.6.block0.proj.conv
# Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: layers.6.block0.proj.bn
# BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: layers.6.block0.residual_quantizer
# Identity()
# ----------
# Layer name: features
# Sequential(
#   (conv): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (activation): SiLU(inplace=True)
# )
# ----------
# Layer name: features.conv
# Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ----------
# Layer name: features.bn
# BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
# ----------
# Layer name: features.activation
# SiLU(inplace=True)
# ----------
# Layer name: classifier
# Sequential(
#   (pooling): AdaptiveAvgPool2d(output_size=1)
#   (squeeze): Flatten()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1280, out_features=1000, bias=True)
# )
# ----------
# Layer name: classifier.pooling
# AdaptiveAvgPool2d(output_size=1)
# ----------
# Layer name: classifier.squeeze
# Flatten()
# ----------
# Layer name: classifier.dropout
# Dropout(p=0.2, inplace=False)
# ----------
# Layer name: classifier.fc
# Linear(in_features=1280, out_features=1000, bias=True)
# ----------
